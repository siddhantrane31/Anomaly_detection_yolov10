# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# fatal: destination path 'yolov10' already exists and is not an empty directory.

# %%
cd yolov10
# Out:
# c:\IRP\fall_detection\yolov10
# c:\Users\siddhant\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\siddhant\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\siddhant\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\siddhant\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: C:\Users\siddhant\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded c:\IRP\fall_detection\yolov10\weights\yolov10n.pt
# Downloaded c:\IRP\fall_detection\yolov10\weights\yolov10s.pt
# Downloaded c:\IRP\fall_detection\yolov10\weights\yolov10m.pt
# Downloaded c:\IRP\fall_detection\yolov10\weights\yolov10b.pt
# Downloaded c:\IRP\fall_detection\yolov10\weights\yolov10x.pt
# Downloaded c:\IRP\fall_detection\yolov10\weights\yolov10l.pt

# %%
# !pip install huggingface_hub
# Out:
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\siddhant\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\siddhant\appdata\local\programs\python\python39\lib\site-packages)

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model= C:\IRP\fall_detection\yolov10\weights\yolov10n.pt  data= C:\IRP\fall_detection\falldataset\datata.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\siddhant\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.161  Python-3.9.10 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=C:\IRP\fall_detection\runs\detect\train13\weights\best.pt source=C:\IRP\fall_detection\nav.mp4
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.10 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 119.0ms
# video 1/1 (frame 2/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 16.0ms
# video 1/1 (frame 3/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 15.1ms
# video 1/1 (frame 4/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 14.1ms
# video 1/1 (frame 5/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 14.8ms
# video 1/1 (frame 6/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 14.9ms
# video 1/1 (frame 7/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 14.8ms
# video 1/1 (frame 8/711) C:\IRP\fall_detection\nav.mp4: 352x640 (no detections), 15.2ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=C:\IRP\fall_detection\runs\detect\train9\weights\best.pt source=C:\IRP\fall_detection\ware.mp4
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.10 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/593) C:\IRP\fall_detection\ware.mp4: 384x640 4 Fall-Detecteds, 128.5ms
# video 1/1 (frame 2/593) C:\IRP\fall_detection\ware.mp4: 384x640 5 Fall-Detecteds, 13.8ms
# video 1/1 (frame 3/593) C:\IRP\fall_detection\ware.mp4: 384x640 5 Fall-Detecteds, 20.3ms
# video 1/1 (frame 4/593) C:\IRP\fall_detection\ware.mp4: 384x640 3 Fall-Detecteds, 13.7ms
# video 1/1 (frame 5/593) C:\IRP\fall_detection\ware.mp4: 384x640 3 Fall-Detecteds, 15.6ms
# video 1/1 (frame 6/593) C:\IRP\fall_detection\ware.mp4: 384x640 3 Fall-Detecteds, 14.1ms
# video 1/1 (frame 7/593) C:\IRP\fall_detection\ware.mp4: 384x640 4 Fall-Detecteds, 20.2ms
# video 1/1 (frame 8/593) C:\IRP\fall_detection\ware.mp4: 384x640 3 Fall-Detecteds, 14.3ms
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=C:\IRP\fall_detection\runs\detect\train9\weights\best.pt source=C:\IRP\fall_detection\fac.mp4
# Out:
# The kernel failed to start as 'has_suggestion' could not be imported from 'c:\Users\siddhant\AppData\Local\Programs\Python\Python39\lib\site-packages\prompt_toolkit\filters\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
